# %%
# VARIABLES:
job_description = """ <> """
current_role = " <> "
current_industry = " <> "
position = " <> "
company = " <> "
my_resume = """ <> """
bullet_point = " <> "
hook_result = " <> "
industry = " <> "

# FOR COVER LETTER
challenges_prompt = f"""Based on this job description, what is the biggest challenge someone in this position would face day-to-day: {job_description}"""
hook_prompt = f"""You are currently working as a {current_role} in the {current_industry} industry and you are applying for this {position} at {company}.
Write an attention grabbing hook for your cover letter that highlights your experience and qualifications in a way that shows you empathise
and can sucessfully take on the challenges of the <position> role. Consider incorporating specific examples of how you've tackled these challenges in your
past work and explore creative ways to express your enthusiasm for the opportunity. Keep your hook within 10 words."""
# hook_result = response for hook_prompt
cover_letter_prompt = f"""You are writing the cover letter for the {position} at {company}. Here's what you have so far: {hook_result}
Finish writing the cover letter baased on your resume and keep it within 250 words. {my_resume}"""
# use hook for para 1 for cover letter
# adjust based on the main challenge AI identifies at {challenges_prompt}
#   highlight 1 of my experience to show how i dealt with this challenge specifically
#   spin ONE of your experiences to show you can deal with this challenge
#   delete other paras to keep cover letter short and to the point

# FOR RESUME
role_prompting = f"""You are an expert resume writer with over 20 years of experience working with job seekers trying to land a role in {industry}.
Highlight the 3 most important responsibilities in this job description: {job_description}"""
resume_prompt = f"""Great! Based on these 3 most important responsibilities from the job description, please tailor my resume for this {position} at {company}
Do not make information up. Here is my resume: {my_resume}"""
difference_prompt = """List out the differences between my original resume and your suggested draft in table format with 2 columns: Original and Updated.
Be specific and list out what was changed, down to the exact wording."""
# difference_prompt is important to catch hullucinations / lies, eg: change in title name

# FOR RESUME BULLET POINTS
bullet_point_init_prompt = f"""You are an expert resume writer with over 20 years of experience. Here's a bullet point I have in my resume. No action needed for now.
If you understand, please respond with "yes" Here is my bullt point: {bullet_point}"""
bullet_point_make_prompt = """Re-write this bullet point using this structure: "I accomplished X by the measure Y that resulted in Z."
For example, "I lowered hospital mortality rate by 10"%" by educating nurses in new protocols which translates to 200 lives saved per year"
Use compelling language and keep the bullet point within 50 words."""
# use quantify_prompt after bullet_point_init_prompt
quantify_prompt = """I don't know how my sucess was measured. Please give me suggestions where and how I can add quantifiable and measurable metrics
in this bullet point"""

# FOR ATS FRIENDLY
keywords_prompt = f"""Hi, can you identify the top 5-10 keywords and skills from this job description. It's for {position}: {job_description}"""
# change the title at top to {position} and 3 key skills right under the title: Graduate DA Intern PowerBI | SQL | Python
# incorporate other kewywords into professional summary and work experience
# keywords must be relevant to your own experiences
resume_summary_prompt = """Can you now help me write a professional resume summary for this position? Highlight <experience>.
Show how my professional background and expertise can address the company's major pain points such as <challenges>.
Mention my notable accomplishment of <accomplishment>. Conclude by emphasising my expertise in <expertise>.
Incorporate keywords from the job posting. limits: max 5 sentences, max 60 words. Do not make up information.
can you please remove pronouns as this is a professional summary."""
reference_summary = " <> "
reference_summary_prompt = f"""Here's an example resume summary you can reference for guidance.
This is for a <custom position>: {reference_summary}"""
bullet_point_convert_prompt = f"""Can you help me develop 4-5 bullet points on my resume for my position as {current_role}?
I'd like them to be impactful and include relevant keywords. Here's what I did; <what I did>"""
resume_improve_prompt = f"""Here's a copy of my resume. Based on the {position} job description I shared earlier, can you provide areas of improvement
and suggestions on how to enhance my resume for this position? More importantly, how can I better tailor my resume to this position? {my_resume}"""

# %%
empty_resume = """
PAMMI SIVAKUMAR (SIVA)	04 5808 7046	psiva.k@outlook.com
GitHub	Graduate – Data Scientist | Developer	LinkedIn
________________________________________
Bio

________________________________________
Relevant Projects

________________________________________
Relevant Work Experience

________________________________________
Relevant Technical & Soft Skills
Technical Skills:
Soft Skills:
________________________________________
Academic Background
•	Master of Information Technology (Database Specialization) – University of New South Wales, Australia (2023 – 2025)
•	Bachelor of Electronics Engineering (Honours) – Singapore University of Social Sciences, Singapore (2015 – 2020)
________________________________________
References: Will be shared on request
________________________________________
Visa: Bridging for 485 (Post-Higher Education Work stream)

"""

# %% [markdown]
# 1️⃣  keywords_prompt
#
# 2️⃣  role_prompting
#
# 3️⃣  resume_prompt
#
# 4️⃣  difference_prompt
#
# 5️⃣  bullet_point_init_prompt & bullet_point_make_prompt
#
# 6️⃣  quantify_prompt
#
# 7️⃣  bullet_point_convert_prompt (optional)
#
# 8️⃣  resume_summary_prompt (+reference_summary_prompt optional)
#
# 9️⃣  resume_improve_prompt
#
# 🔟  challenges_prompt
#
# 1️⃣1️⃣ hook_prompt
#
# 1️⃣2️⃣ cover_letter_prompt

# %%
about_me = """
About me:
graduate from Master in IT from UNSW
wants to get a role to start career in IT
looking for roles in development, programming and data - web developer, front end developer, back end developer, systems developer, software engineer, app developer, data scientist, data analyst, data engineer, business analyst
I am living in Sydney, but I am Willing to relocate
I am currently working on learning more data analysis tools like PowerBI, advanced Excel and tableau.
technical knowledge in engineering and IT
domain knowledge in agriculture (harvesting), sales and customer service (consumer electronics and fashion)
I have a proven track record of adapting to various work environments, demonstrating strong problem-solving capabilities,
and maintaining high standards of operational efficiency and customer satisfaction.

What I have learnt:
HTML, CSS, C, C++, PYTHON, SQL, RUST
AI, NEURAL NETWORK, COMPUTER VISION, MACHINE LEARNING, BIG DATA WITH APACHE SPARK AND HADOOP
WEB DEVELOPMENT - FRONT, BACK, FULL STACK, FLASK API, REST API
MS OFFICE - WORD, EXCEL, POWERPOINT, TEAMS, VISIO, OUTLOOK
ADOBE - PHOTOSHOP, ILLUSTRATOR, AUDITION, AFTER EFFECTS, ACROBAT (PDF)
PANDAS, KERAS, TENSORFLOW, PYTORCH, OPENCV, NLTK, MATHPLOTLIB, NUMPY, FLASK, CHATGPT API
PROMPT ENGINEERING, FEATURE ENGINEERING, POWERBI, TABLEAU, JUPYTER, CI/CD, POSTGRESQL, PGSQL, POSTGRES
SHELL SCRIPTING, DOCKER, BASH
data tasks: extraction, manipulation, visualisation, extract, transform, load, governance,
classification, mapping, insights, reporting, flow, flow models, integrity, profiling
"""

# %%
my_resume = f"""
PAMMI SIVAKUMAR (SIVA)	04 5808 7046	psiva.k@outlook.com
________________________________________
{about_me}
________________________________________
RELEVANT Projects – remove if not required
•	Data Analysis:
	POP Quiz 5 (csv) – csv data extraction: Comparative Analysis of Agricultural and Forest Expansion
	DBMS Proj (pgSQL) – Medium/Large DB querying: Querying University Database System
	DSE A1 (Pandas) – Data Extract and Transform): Data Ingestion, Manipulation, and Visualisation
•	Data Engineering:
	BDM A1 (): Anomaly detection from sensor readings
	BDM A2 (): Frequent item set mining in E-commerce transaction logs
	BDM A3 (): Similarity Join in E-commerce Transaction Logs
	DB Imp A1(): Adding Data Types to PostgreSql
	DB Imp A2(): Multi-Attribute Linear Hashed Files
•	Data Science:
	DSE A3 (ML, ETL): Insurance Policy Analysis and Prediction System
•	AI:
	AI A1 (RL): Reward-based learning agents
	AI A2 (NN): Multi-layer neural networks
	CV Grp Proj (UNet): Semantic Segmentation Methods for Natural Environment Images
	NN Grp Proj (NLP): Emotion Classification using Tweets
•	Development:
	DSE A2 (Flask API): Smart API for the Deutsche Bahn
	IRWS Proj (NLTK): Ranked Retrieval
	ITP (XML and API): AI for Language Learning
	Personal - convenience tools

________________________________________
RELEVANT Work Experience – remove if not required

Sales assistant
Mohamed Mustafa Samsudin, Singapore | December 2015 - June 2018 February 2019 - December 2019
Departments: Telephone, Personal audio (headphones & speakers) and Mobile phone
•	Provide exceptional service by greeting customers, answering inquiries, handling complaints, and managing returns and exchanges to ensure customer satisfaction.
•	Monitor stock levels, organize inventory storage.
•	Assist with inventory counts, maintain accurate sales records.
•	Collaborate with team members, discuss sales strategies, provide feedback on customer preferences, and assist colleagues during busy periods.
•	Promote products through cross-selling and upselling, assist with technical support, follow security protocols to prevent theft, and ensure the sales floor is clean and well-maintained.

Picker
ADGL Serra, Atherton region, Queensland | March 2020 - June 2020
•	Carefully pick avocados by hand or with tools, ensuring fruit is not damaged, and follow proper picking techniques to maintain quality.
•	Collaborate with other crew members, communicate effectively to coordinate picking schedules and tasks, and support colleagues during peak harvesting periods.
•	Maintain and clean picking tools and equipment, follow safety guidelines and protocols, and perform other duties as assigned by the farm manager.

Housekeeping crew member
City Backpackers HQ, Brisbane | September 2020 - December 2020
•	Maintain cleanliness by cleaning kitchen, bathrooms, and public areas, ensuring all spaces are hygienic and presentable.
•	Inventory Management: Monitor and restock cleaning supplies and toiletries and report any inventory shortages to maintain adequate stock levels.
•	Report completed tasks and maintenance issues.
•	Collaborate with other housekeeping staff and hostel employees, communicate effectively to ensure efficient operations, and assist colleagues during busy periods.
•	Follow health and safety guidelines, handle lost and found items, address guest inquiries and requests, and perform other duties as assigned by the housekeeping manager.

Kitchen hand
Gusto Da Gianni, Brisbane | November 2020 – March 2021, November 2021 – January 2022
•	Assist in preparing ingredients by washing, chopping, and portioning food items, ensuring they are ready for cooking.
•	Maintain cleanliness by washing dishes, utensils, and kitchen equipment, and sanitize work surfaces to ensure a hygienic kitchen environment.
•	Restock kitchen supplies, and ensure ingredients are stored properly to maintain freshness and prevent waste.
•	Collaborate with chefs and kitchen staff, communicate effectively to ensure smooth kitchen operations, and support colleagues during busy periods.
•	Dispose of garbage, manage recycling, follow health and safety guidelines, and perform other duties as assigned by the kitchen manager and chefs.
•	Reinforce in times of high volume of service (busy times)

Picker
N&N Donaldson and Co, Bundaberg region, Queensland | March 2021 - May 2021
•	Carefully pick avocados by hand or with tools, ensuring fruit is not damaged, and follow proper picking techniques to maintain quality.
•	Collaborate with other crew members, communicate effectively to coordinate picking schedules and tasks, and support colleagues during peak harvesting periods.
•	Maintain and clean picking tools and equipment, follow safety guidelines and protocols, and perform other duties as assigned by the farm manager.

Picker, Farm hand
Simpsons Farms, Bundaberg region, Queensland | May 2021 - September 2021
•	Carefully pick avocados by hand or with tools, ensuring fruit is not damaged, and follow proper picking techniques to maintain quality.
•	Collaborate with other crew members, communicate effectively to coordinate picking schedules and tasks, and support colleagues during peak harvesting periods.
•	Maintain and clean picking tools and equipment, follow safety guidelines and protocols, assist with farm maintenance tasks, and perform other duties as assigned by the farm manager.

Sales Consultant, IT Support and Stock Coordinator
APG & Co (Sportscraft, SABA), Sydney | 2022 – Present
Key Responsibilities:
•	Worked across multiple stores, adapting to different retail environments and management / operational styles and different customer bases.
•	As Sales Consultant – retail and customer service, team-player:
	Deliver exceptional customer-focused service, ensuring seamless transactions.
	Consistently strive to meet store and individual productivity targets
	Become an expert in product knowledge, fabrication and personal styling to enhance the customer experience
	Stay informed about the latest products, enabling you to share valuable insights with customers.
	Contribute to the efficient operation of the store by effectively managing stock and implementing loss prevention measures.
	Maintain visual merchandising standards to uphold the brand's image.
	Process Online (postal) orders and Click & Collect orders in a self-established processing pipeline.
	Collaborate with team members, discuss sales strategies, provide feedback on customer preferences, and assist colleagues during busy periods.
	Provide exceptional service by greeting customers, answering inquiries, handling complaints, and managing returns and exchanges to ensure customer satisfaction.
	Promote products through cross-selling and upselling, assist with technical support, follow security protocols to prevent theft, and ensure the sales floor is clean and well-maintained.
	Assist with customer accounts and manage billing and payments.
•	As Ad Hoc IT Support – expertise in basic IT troubleshooting:
	Assist the management in basic IT troubleshooting issues before escalating to the IT support – mainly regarding Apparel 21 POS applications, MS Office applications and printing.
	Achievement: Improved initial roster planner sheet to make it more visible (increase font size to help readability), removing redundant features (removed unnecessary rows where no one uses the information we are supposed to provide) and implementing new useful features (hours budget tracker – user gives allocated hours. Total hours calculated from the roster, remainder or overflow is shown to make things easy for the management).
•	As Stock Coordinator:
	Stock management and organisation
	Unpacking weekly deliveries
	Transferring stock and managing all stock replenishment
	Supporting management in all stock operations
	Supporting sales team by accessing stock for clients
	Assist with inventory counts, maintain accurate sales records.
	Monitor stock levels, organize inventory storage.
________________________________________
RELEVANT Technical & Soft Skills – remove if not required
Technical Skills:
Python, SQL, ETL, CI / CD, GitHub, Excel, Machine Learning, Rust, C, C++, Apache Spark, Hadoop, Jupyter, Python libraries and frameworks for Data, AI and Development, Machine Learning, APIs, Flask, scripting, task automation, develop tools for small tasks (convert document format, renaming files and directories, updating python libraries), HTML 5, CSS 3, Docker, Feature engineering, prompt engineering, MS Office
Data: extraction, transformation, loading, pipeline, process pipeline, modelling, manipulation, visualisation, governance, classification, mapping, insights, reporting, flow, flow models, integrity, profiling
Soft Skills:
Customer service, Inventory management, Team collaboration, Operational efficiency, Technical and sales support, communication, attention to detail, customer relations, time management, problem solving, Flexible, innovation, adaptable
________________________________________
Academic Background
•	Master of Information Technology (Database Specialization) – University of New South Wales, Australia (2023 – 2024)
•	Bachelor of Electronics Engineering (Honours) – Singapore University of Social Sciences, Singapore (2015 – 2019)
________________________________________
References:
•	Will be shared on request
________________________________________
Visa:
•	Bridging for 485
"""

# %%
job_description = """
Your career adventure starts here 
We believe your career should be a rewarding adventure. Whether you’re passionate about solving complex challenges, delivering strategic advice, or collaborating with clients and experts across Asia Pacific, our award-winning Graduate Programme offers you the opportunity to discover, grow, and succeed. 

Opportunities are available across Sydney, Brisbane & Adelaide in our Digital & Data Analytics team. This team utilises big data, advanced analytics, machine learning and artificial intelligence to transform how our clients operate. 

To find out where your degree fits at Aurecon, check out our Teams & Degree Matrix. 

What’s it like to be an Aureconeer?
As a Digital & Data Analytics Consultant in our Asset Management & Performance team at Aurecon, you’ll work on diverse, meaningful projects and be part of a team that thrives on solving challenges, driving strategy, and delivering results for clients. 

Here’s a glimpse of your adventure: 

Real-world projects: Collaborate with experts to tackle key business challenges, deliver practical solutions, and shape strategic outcomes for clients and communities. 

Making a difference: Create positive change through community partnerships and volunteer Handprint Days.  

Climbing new heights: Access interactive learning, coaching, and mentoring to develop into an effective consultant, strategist, and future leader. 

A network of explorers: Join Limelight, our Early Careers Network, where you’ll connect with peers and senior professionals, share experiences, and collaborate on innovative solutions. 

Flexibility on your journey: Our hybrid working model lets you balance work, life, and the adventure that comes with both. 

Your adventure essentials: what you’ll bring  
As you embark on your career journey, we’re looking for people who are eager to learn, collaborate, and bring fresh thinking to the table. You’ll come with: 

A relevant degree (or expected completion) in Data Science, Computer Science, Mechatronics Engineering or related double degree. 

An analytical mindset and the ability to solve complex problems with creative, practical solutions. 

Strong communication and interpersonal skills to collaborate with teams and engage with clients. 

A passion for making an impact and driving positive change. 

A thirst for learning, growth, and gaining new experiences. 

How will your adventure be shaped by us?  
Adventure is for everyone—we celebrate individuality and believe your unique perspectives will help shape a better future. Wherever your journey takes you, we’ll support you every step of the way. 

Our leadership, policies, and behaviours foster a culture where everyone belongs. We are committed to increasing representation and creating opportunities for Indigenous Australians, gender diversity, people with disability, and veterans, ensuring our workforce reflects the communities we serve. 

Our teams work on award-winning projects that shape the future, from renewable energy solutions across Australia, the revitalisation of New Zealand’s transport systems, to transforming cities with smart infrastructure across Asia.  

Beyond meaningful work and exciting projects, we offer a competitive salary, flexible hours, remote work options, working holidays, paid parental leave, cultural holiday swaps, and a wellbeing platform for you and your family. 

 
Ready to bring ideas to life? 
Your career adventure starts here. We encourage candidates from all backgrounds to apply – including those who may not meet every single requirement – if the role aligns with your strengths and passions, we want to hear from you. If you need any adjustments during the application process, please email WorkplaceAdjustment@aurecongroup.com. 

Apply now and discover your rewarding adventure.
"""

# %%
enhancer = """1. No headline or title at the top

Your name is not your identity.
Recruiters want to know what role you’re targeting within seconds.
Without a clear title like “Data Analyst” or “Business Intelligence Specialist”, you’re just another generic profile.
✅ Fix: Add a headline below your name:
example: “Data Analyst | Power BI | SQL | Business Insights”
This instantly sets the context.

2. Weak summary section

Most summaries are just a dump of tools:
example: “Experienced with Excel, Python, Tableau…”
But that doesn’t tell a story.
✅ Fix: Talk outcomes, not just tools:
example: “Built dashboards that reduced inventory errors by 15% and improved warehouse efficiency by 20%.”
Make your value obvious.

3. Generic skill section

“Teamwork” and “Problem-solving” show up on 99% of resumes. And they don’t help.
✅ Fix: Use the skills section for ATS-friendly keywords:
SQL | Power BI | Data Cleaning | A/B Testing | Python | Data Visualization
Tailor these to the job description.

4. Quantified results, but no context

Saying “reduced cost by 10%” is good. But how did you do it?
✅ Fix: Use the Action + Tool + Result format:
example: “Automated reporting with Python, saving 10+ hours/week and reducing manual errors by 30%.”
Show your method, not just the result.

5. No portfolio link or GitHub

For a data analyst, this is a big miss. Recruiters want proof. Your resume is the pitch, but your portfolio is the evidence.
✅ Fix: Add a portfolio or GitHub link at the top or bottom of your resume.
Highlight 2–3 projects that show your thinking and skills.

6. No objective or role alignment

No, not the cliche “Seeking a challenging role…” line. That’s fluff.
✅ Fix: Write a 1-liner that shows intent:
example: “Looking to leverage 3+ years of analytics experience to drive decision-making in a fast-paced product company.”
Direction matters.

Small tweaks can completely change how recruiters see you.
They’re not reading between the lines, so make every line count.

State the impact of your work in the bullet points or impact of project in the description.
"""

# %%
from openai import OpenAI
import tiktoken

client = OpenAI(api_key="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")

# Initialize conversation history
messages = []

def count_tokens(text):
    encoding = tiktoken.get_encoding("cl100k_base")  # Use "p50k_base" for GPT-3 models
    return len(encoding.encode(text))

total_tokens = 0 # Token tracker

# %%
position = " Graduate Digital & Data Analytics Consultant "
# job_description = " <> "

keywords_prompt = f"""Hi, can you identify the top 5-10 keywords and skills from this job description.
It's for {position}: {job_description}"""

messages.append({"role": "user", "content": keywords_prompt})
keywords_response = client.chat.completions.create(model="gpt-4o", messages=messages)
keywords_result = keywords_response.choices[0].message.content
messages.append({"role": "assistant", "content": keywords_result})  # Store AI response

result_tokens = count_tokens(keywords_result) + count_tokens(keywords_prompt)
total_tokens += result_tokens
remaining_tokens = 128000 - total_tokens

print(f"Tokens: This result = {result_tokens}\tTotal = {total_tokens}\tRemaining = {remaining_tokens}")
print("Keywords & Skills:\n", keywords_result)

# %%
industry = " IT / Technology / Computer Science "
# job_description = " <> "

role_prompt = f"""You are an expert resume writer with over 20 years of experience working with job seekers
trying to land a role in {industry}. Highlight the 3 most important responsibilities in this job description:
{job_description}"""

messages.append({"role": "user", "content": role_prompt})
role_response = client.chat.completions.create(model="gpt-4o", messages=messages)
role_result = role_response.choices[0].message.content
messages.append({"role": "assistant", "content": role_result})  # Store AI response

result_tokens = count_tokens(role_result) + count_tokens(role_prompt)
total_tokens += result_tokens
remaining_tokens = 128000 - total_tokens

print(f"Tokens: This result = {result_tokens}\tTotal = {total_tokens}\tRemaining = {remaining_tokens}")
print("Key Responsibilities:\n", role_result)

# %%
# position = " <> "
company = " Aurecon Group Pty Ltd, Australia "
# my_resume = " <> "

resume_prompt = f"""Great! Based on these 3 most important responsibilities from the job description:
{role_result}
please tailor my resume for this {position} at {company}. Do not make information up. Here is my resume:
{my_resume}
Keep in mind the points from enhancer:
{enhancer}"""

messages.append({"role": "user", "content": resume_prompt})
resume_response = client.chat.completions.create(model="gpt-4o", messages=messages)
resume_result = resume_response.choices[0].message.content
messages.append({"role": "assistant", "content": resume_result})  # Store AI response

result_tokens = count_tokens(resume_result) + count_tokens(resume_prompt)
total_tokens += result_tokens
remaining_tokens = 128000 - total_tokens

print(f"Tokens: This result = {result_tokens}\tTotal = {total_tokens}\tRemaining = {remaining_tokens}")
print("Tailored Resume:\n", resume_result)

# %%
difference_prompt = f"""List out the differences between my original resume and your suggested draft
in table format with 2 columns: Original and Updated. Be specific and list out what was changed,
down to the exact wording.
{my_resume}
{resume_result}
"""

messages.append({"role": "user", "content": difference_prompt})
difference_response = client.chat.completions.create(model="gpt-4o", messages=messages)
difference_result = difference_response.choices[0].message.content
messages.append({"role": "assistant", "content": difference_result})  # Store AI response

result_tokens = count_tokens(difference_result) + count_tokens(difference_prompt)
total_tokens += result_tokens
remaining_tokens = 128000 - total_tokens

print(f"Tokens: This result = {result_tokens}\tTotal = {total_tokens}\tRemaining = {remaining_tokens}")
print("Resume Differences:\n", difference_result)

# %%
bullet_point = " <> "

bullet_point_init_prompt = f"""You are an expert resume writer with over 20 years of experience.
Here's a bullet point I have in my resume. No action needed for now. If you understand, please respond with "yes"
Here is my bullet point: {bullet_point}"""

messages.append({"role": "user", "content": bullet_point_init_prompt})
bullet_init_response = client.chat.completions.create(model="gpt-4o", messages=messages)
bullet_init_result = bullet_init_response.choices[0].message.content
messages.append({"role": "assistant", "content": bullet_init_result})  # Store AI response

result_tokens = count_tokens(bullet_init_result) + count_tokens(bullet_point_init_prompt)
total_tokens += result_tokens
remaining_tokens = 128000 - total_tokens

print(f"Tokens: This result = {result_tokens}\tTotal = {total_tokens}\tRemaining = {remaining_tokens}")
print("Bullet Point Acknowledgment:\n", bullet_init_result)

# %%
bullet_point_make_prompt = """Re-write this bullet point using this structure: "I accomplished X by the measure Y
that resulted in Z." For example, "I lowered hospital mortality rate by 10% by educating nurses in new protocols
which translates to 200 lives saved per year" Use compelling language and keep the bullet point within 50 words."""

messages.append({"role": "user", "content": bullet_point_make_prompt})``
bullet_make_response = client.chat.completions.create(model="gpt-4o", messages=messages)
bullet_make_result = bullet_make_response.choices[0].message.content
messages.append({"role": "assistant", "content": bullet_make_result})  # Store AI response

result_tokens = count_tokens(bullet_make_result) + count_tokens(bullet_point_make_prompt)
total_tokens += result_tokens
remaining_tokens = 128000 - total_tokens

print(f"Tokens: This result = {result_tokens}\tTotal = {total_tokens}\tRemaining = {remaining_tokens}")
print("Improved Bullet Point:\n", bullet_make_result)

# %%
quantify_prompt = """I don't know how my sucess was measured. Please give me suggestions where and how
I can add quantifiable and measurable metrics in this bullet point"""

messages.append({"role": "user", "content": quantify_prompt})
quantify_response = client.chat.completions.create(model="gpt-4o", messages=messages)
quantify_result = quantify_response.choices[0].message.content
messages.append({"role": "assistant", "content": quantify_result})  # Store AI response

result_tokens = count_tokens(quantify_result) + count_tokens(quantify_prompt)
total_tokens += result_tokens
remaining_tokens = 128000 - total_tokens

print(f"Tokens: This result = {result_tokens}\tTotal = {total_tokens}\tRemaining = {remaining_tokens}")
print("Quantify Bullet Point:\n", quantify_result)

# %%
current_role = " Casual Sales Consultant, Stock manager, IT Support "
what_I_did = " <> "

bullet_point_convert_prompt = f"""Can you help me develop 4-5 bullet points on my resume for my position as
{current_role}? I'd like them to be impactful and include relevant keywords. Here's what I did: {what_I_did}"""

messages.append({"role": "user", "content": bullet_point_convert_prompt})
convert_response = client.chat.completions.create(model="gpt-4o", messages=messages)
convert_result = convert_response.choices[0].message.content
messages.append({"role": "assistant", "content": convert_result})  # Store AI response

result_tokens = count_tokens(convert_result) + count_tokens(bullet_point_convert_prompt)
total_tokens += result_tokens
remaining_tokens = 128000 - total_tokens

print(f"Tokens: This result = {result_tokens}\tTotal = {total_tokens}\tRemaining = {remaining_tokens}")
print("Converted Bullet Points:\n", convert_result)

# %%
experience = " <> "
# challenges = " <> " -> role_result
accomplishment = " <> "
expertise = " <> "

resume_summary_prompt = f"""Can you now help me write a professional resume summary for this position?
Highlight {experience}. Show how my professional background and expertise can address the company's major
pain points such as {role_result}. Mention my notable accomplishment of {accomplishment}. Conclude by emphasising
my expertise in {expertise}. Incorporate keywords from the job posting. Limits: max 5 sentences, max 60 words.
Do not make up information. Can you please remove pronouns as this is a professional summary."""

messages.append({"role": "user", "content": resume_summary_prompt})
summary_response = client.chat.completions.create(model="gpt-4o", messages=messages)
summary_result = summary_response.choices[0].message.content
messages.append({"role": "assistant", "content": summary_result})  # Store AI response

result_tokens = count_tokens(summary_result) + count_tokens(resume_summary_prompt)
total_tokens += result_tokens
remaining_tokens = 128000 - total_tokens

print(f"Tokens: This result = {result_tokens}\tTotal = {total_tokens}\tRemaining = {remaining_tokens}")
print("Resume Summary:\n", summary_result)

# %%
# position = " <> "

resume_improve_prompt = f"""Here's a copy of my resume. Based on the {position} job description:
{job_description}
I shared earlier,
can you provide areas of improvement and suggestions on how to enhance my resume for this position?
More importantly, how can I better tailor my resume to this position? {resume_result}"""

messages.append({"role": "user", "content": resume_improve_prompt})
resume_improve_response = client.chat.completions.create(model="gpt-4o", messages=messages)
resume_improve_result = resume_improve_response.choices[0].message.content
messages.append({"role": "assistant", "content": resume_improve_result})  # Store AI response

result_tokens = count_tokens(resume_improve_result) + count_tokens(resume_improve_prompt)
total_tokens += result_tokens
remaining_tokens = 128000 - total_tokens

print(f"Tokens: This result = {result_tokens}\tTotal = {total_tokens}\tRemaining = {remaining_tokens}")
print("Resume Improvement Suggestions:\n", resume_improve_result)

# %%
redo_resume_prompt = f"""taking into consideration the following:
{resume_improve_result} and {enhancer}
and based on the initial
{job_description} and {my_resume}
please improve {resume_result}
"""

messages.append({"role": "user", "content": redo_resume_prompt})
redo_resume_response = client.chat.completions.create(model="gpt-4o", messages=messages)
redo_resume_result = redo_resume_response.choices[0].message.content
messages.append({"role": "assistant", "content": redo_resume_result})  # Store AI response

result_tokens = count_tokens(redo_resume_result) + count_tokens(redo_resume_prompt)
total_tokens += result_tokens
remaining_tokens = 128000 - total_tokens

print(f"Tokens: This result = {result_tokens}\tTotal = {total_tokens}\tRemaining = {remaining_tokens}")
print("Cover Letter Hook:\n", redo_resume_result)

# %%
current_role = " Sales Consultant, IT Support, and Stock Coordinator "
current_industry = " Fashion retail "
# position = " <> "
# company = " <> "

hook_prompt = f"""You are currently working as a {current_role} in the {current_industry} industry
and you are applying for this {position} at {company}. Write an attention grabbing hook for your
cover letter that highlights your experience and qualifications in a way that shows you empathise 
and can sucessfully take on the challenges of the {position} role. Consider incorporating specific
examples of how you've tackled these challenges in your past work and explore creative ways to express
your enthusiasm for the opportunity. Keep your hook within 25 words."""

messages.append({"role": "user", "content": hook_prompt})
hook_response = client.chat.completions.create(model="gpt-4o", messages=messages)
hook_result = hook_response.choices[0].message.content
messages.append({"role": "assistant", "content": hook_result})  # Store AI response

result_tokens = count_tokens(hook_result) + count_tokens(hook_prompt)
total_tokens += result_tokens
remaining_tokens = 128000 - total_tokens

print(f"Tokens: This result = {result_tokens}\tTotal = {total_tokens}\tRemaining = {remaining_tokens}")
print("Cover Letter Hook:\n", hook_result)

# %%
# position = " <> "
# company = " <> "

cover_letter_prompt = f"""You are writing the cover letter for the {position} at {company}.
Here's what you have so far: {hook_result} Finish writing the cover letter based on your resume
and keep it within 250 words. {redo_resume_result}"""

messages.append({"role": "user", "content": cover_letter_prompt})
cover_response = client.chat.completions.create(model="gpt-4o", messages=messages)
cover_result = cover_response.choices[0].message.content
messages.append({"role": "assistant", "content": cover_result})  # Store AI response

result_tokens = count_tokens(cover_result) + count_tokens(cover_letter_prompt)
total_tokens += result_tokens
remaining_tokens = 128000 - total_tokens

print(f"Tokens: This result = {result_tokens}\tTotal = {total_tokens}\tRemaining = {remaining_tokens}")
print("Cover Letter:\n", cover_result)

# %%
for m in messages:
    print(f"{m["role"].capitalize()}: {m["content"]}\n")
